# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Full Restaurant Reviews Dataset

# %%
# Aaron's file structure
# reviews_df = pd.read_json("../../dataset/restaurant_reviews.json", lines=True)

# Alex's file structure
reviews_df = pd.read_json("../../full_dataset/restaurant_reviews.json", lines=True)

# %%
reviews_df.head()
# Out:
#               business_id  cool       date  funny  stars  \
# 0  --6MefnULPED_I942VcFNA     0 2017-08-17      0      4
# 1  --6MefnULPED_I942VcFNA     0 2017-05-31      0      3
# 2  --6MefnULPED_I942VcFNA     0 2016-10-23      0      2
# 3  --6MefnULPED_I942VcFNA     0 2017-07-30      0      2
# 4  --6MefnULPED_I942VcFNA     0 2017-02-07      1      2
#
#                                                 text  useful  \
# 0  This is one of my top 3 places to get BBQ pork...       2
# 1  This restaurant is famous for their BBQ dishes...       0
# 2  Roasted pork is one of my favorite things... A...       1
# 3  I walked by the restaurant more than 5 years a...       1
# 4  I came here to order a roast duck over rice to...       0
#
#                   user_id
# 0  FEg8v92qx3kK4Hu4TF28Fg
# 1  HPtjvIrhzAUkKsiVkeT4MA
# 2  MpvqV7lQcl15rflTBEUhXA
# 3  x-Gbs8sVid3yhJIoHD6Gfw
# 4  7Dykd1HolQx8mKPYhYDYSg

# %% [markdown]
# ## Filter Only to Users with > 5 Reviews

# %%
review_counts_df = reviews_df.groupby('user_id').agg('count')['business_id']

# %%
review_counts_df = review_counts_df[review_counts_df > 5]
review_counts_df.shape
# Out:
# (111200,)

# %%
final_reviews_df = reviews_df.set_index('user_id').join(review_counts_df, rsuffix="_r", how='inner').drop('business_id_r', axis=1)

# %%
final_reviews_df.head()
# Out:
#                                    business_id  cool       date  funny  stars  \
# user_id
# ---1lKK3aKOuomHnwAkAow  --9e1ONYQuAa-CB_Rrw7Tw     0 2008-11-11      0      4
# ---1lKK3aKOuomHnwAkAow  1JgaRBX0oiRsvEhHF3ZMjw     1 2011-02-16      7      1
# ---1lKK3aKOuomHnwAkAow  2BbFeotL85cIaBjSq1SWiA     1 2010-10-17      1      1
# ---1lKK3aKOuomHnwAkAow  5aeR9KcboZmhDZlFscnYRA     0 2013-01-16      0      5
# ---1lKK3aKOuomHnwAkAow  5cbsjFtrntUAeUx51FaFTg     0 2010-11-05      0      1
#
#                                                                      text  \
# user_id
# ---1lKK3aKOuomHnwAkAow  So when you go to a restaurant like this pleas...
# ---1lKK3aKOuomHnwAkAow  Food was 30 mins late and the pizza guy thinks...
# ---1lKK3aKOuomHnwAkAow  When you say your a vegetarian don't recomend ...
# ---1lKK3aKOuomHnwAkAow  So Fresh Mama let us host a Homeschool Board G...
# ---1lKK3aKOuomHnwAkAow  So I was coming here once a month or so maybe ...
#
#                         useful
# user_id
# ---1lKK3aKOuomHnwAkAow       0
# ---1lKK3aKOuomHnwAkAow       5
# ---1lKK3aKOuomHnwAkAow       2
# ---1lKK3aKOuomHnwAkAow       1
# ---1lKK3aKOuomHnwAkAow       1

# %%
final_reviews_df['user_id'] = final_reviews_df.index
final_reviews_df.head()
# Out:
#                                    business_id  cool       date  funny  stars  \
# user_id
# ---1lKK3aKOuomHnwAkAow  --9e1ONYQuAa-CB_Rrw7Tw     0 2008-11-11      0      4
# ---1lKK3aKOuomHnwAkAow  1JgaRBX0oiRsvEhHF3ZMjw     1 2011-02-16      7      1
# ---1lKK3aKOuomHnwAkAow  2BbFeotL85cIaBjSq1SWiA     1 2010-10-17      1      1
# ---1lKK3aKOuomHnwAkAow  5aeR9KcboZmhDZlFscnYRA     0 2013-01-16      0      5
# ---1lKK3aKOuomHnwAkAow  5cbsjFtrntUAeUx51FaFTg     0 2010-11-05      0      1
#
#                                                                      text  \
# user_id
# ---1lKK3aKOuomHnwAkAow  So when you go to a restaurant like this pleas...
# ---1lKK3aKOuomHnwAkAow  Food was 30 mins late and the pizza guy thinks...
# ---1lKK3aKOuomHnwAkAow  When you say your a vegetarian don't recomend ...
# ---1lKK3aKOuomHnwAkAow  So Fresh Mama let us host a Homeschool Board G...
# ---1lKK3aKOuomHnwAkAow  So I was coming here once a month or so maybe ...
#
#                         useful                 user_id
# user_id
# ---1lKK3aKOuomHnwAkAow       0  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       5  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       2  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       1  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       1  ---1lKK3aKOuomHnwAkAow

# %%
# Aaron's file structure
# final_reviews_df.to_json('../../dataset/restaurant_reviews_final.json', orient='records', lines=True)

# Alex's file structure
final_reviews_df.to_json('../../full_dataset/restaurant_reviews_final.json', orient='records', lines=True)

# %% [markdown]
# ## Split Final Reviews Dataset by Train/Test, Split by User

# %%
# y_train and y_test is not used here, we just need the train and test user IDs
X_train, X_test, y_train, y_test = train_test_split(final_reviews_df.user_id.unique(), 
                                                    final_reviews_df.user_id.unique(), 
                                                    test_size=0.2, 
                                                    random_state=123)

# %%
final_reviews_train_df = final_reviews_df[final_reviews_df.user_id.isin(X_train)]
print(final_reviews_train_df.shape)
final_reviews_train_df.head()
# Out:
# (1500464, 8)
#                                    business_id  cool       date  funny  stars  \
# user_id
# ---1lKK3aKOuomHnwAkAow  --9e1ONYQuAa-CB_Rrw7Tw     0 2008-11-11      0      4
# ---1lKK3aKOuomHnwAkAow  1JgaRBX0oiRsvEhHF3ZMjw     1 2011-02-16      7      1
# ---1lKK3aKOuomHnwAkAow  2BbFeotL85cIaBjSq1SWiA     1 2010-10-17      1      1
# ---1lKK3aKOuomHnwAkAow  5aeR9KcboZmhDZlFscnYRA     0 2013-01-16      0      5
# ---1lKK3aKOuomHnwAkAow  5cbsjFtrntUAeUx51FaFTg     0 2010-11-05      0      1
#
#                                                                      text  \
# user_id
# ---1lKK3aKOuomHnwAkAow  So when you go to a restaurant like this pleas...
# ---1lKK3aKOuomHnwAkAow  Food was 30 mins late and the pizza guy thinks...
# ---1lKK3aKOuomHnwAkAow  When you say your a vegetarian don't recomend ...
# ---1lKK3aKOuomHnwAkAow  So Fresh Mama let us host a Homeschool Board G...
# ---1lKK3aKOuomHnwAkAow  So I was coming here once a month or so maybe ...
#
#                         useful                 user_id
# user_id
# ---1lKK3aKOuomHnwAkAow       0  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       5  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       2  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       1  ---1lKK3aKOuomHnwAkAow
# ---1lKK3aKOuomHnwAkAow       1  ---1lKK3aKOuomHnwAkAow

# %%
final_reviews_test_df = final_reviews_df[final_reviews_df.user_id.isin(X_test)]
print(final_reviews_test_df.shape)
final_reviews_test_df.head()
# Out:
# (373155, 8)
#                                    business_id  cool       date  funny  stars  \
# user_id
# --2vR0DIsmQ6WfcSzKWigw  7dHYudt6OOIjiaxkSvv3lQ   197 2017-11-08    179      5
# --2vR0DIsmQ6WfcSzKWigw  9edPSkfXKsJmkZYIaOmA7Q   194 2017-11-06    176      4
# --2vR0DIsmQ6WfcSzKWigw  El4FC8jcawUVgw_0EIcbaQ   122 2015-10-13    109      4
# --2vR0DIsmQ6WfcSzKWigw  GHS1rVjO-RMcRB6WJLpCDQ   108 2015-09-16     94      3
# --2vR0DIsmQ6WfcSzKWigw  IhlKa2x5J4vr47hjDY8Jnw    11 2013-06-02      7      5
#
#                                                                      text  \
# user_id
# --2vR0DIsmQ6WfcSzKWigw  Auf unserer Rundreise haben wir häufig die Res...
# --2vR0DIsmQ6WfcSzKWigw  Nachdem wir die Las Vegas North Premium Outlet...
# --2vR0DIsmQ6WfcSzKWigw  Das MGM Grand ist mit seinen 6.853 Zimmern ein...
# --2vR0DIsmQ6WfcSzKWigw  In Las Vegas kann man zwischen zwei verschiede...
# --2vR0DIsmQ6WfcSzKWigw  Bei einer meiner letzten Besuche in Stuttgart ...
#
#                         useful                 user_id
# user_id
# --2vR0DIsmQ6WfcSzKWigw     203  --2vR0DIsmQ6WfcSzKWigw
# --2vR0DIsmQ6WfcSzKWigw     199  --2vR0DIsmQ6WfcSzKWigw
# --2vR0DIsmQ6WfcSzKWigw     130  --2vR0DIsmQ6WfcSzKWigw
# --2vR0DIsmQ6WfcSzKWigw     112  --2vR0DIsmQ6WfcSzKWigw
# --2vR0DIsmQ6WfcSzKWigw      15  --2vR0DIsmQ6WfcSzKWigw

# %%
# Aaron's file structure
# final_reviews_train_df.to_json('../../dataset/restaurant_reviews_final_train.json', orient='records', lines=True)

# Alex's file structure
final_reviews_train_df.to_json('../../full_dataset/restaurant_reviews_final_train.json', orient='records', lines=True)

# %%
# Aaron's file structure
# final_reviews_test_df.to_json('../../dataset/restaurant_reviews_final_test.json', orient='records', lines=True)

# Alex's file structure
final_reviews_test_df.to_json('../../full_dataset/restaurant_reviews_final_test.json', orient='records', lines=True)
